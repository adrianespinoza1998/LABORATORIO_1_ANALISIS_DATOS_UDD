# %% [markdown]
# # Justificacion de porque elegimos este dataset
#
# La selección de este dataset se fundamenta en la relevancia del problema de salud que aborda. Si bien a nivel mundial la incidencia del cáncer de vesícula biliar es relativamente baja, en Chile esta patología presenta una frecuencia significativamente mayor, ubicándose dentro de los diez tipos de cáncer más comunes del país y superando el promedio internacional.
#
# En este contexto, disponer de un conjunto de datos que permita analizar esta enfermedad resulta particularmente valioso, dado que posibilita la generación de conocimiento sobre un problema de salud pública de alta prioridad nacional. Además, el estudio de este dataset ofrece la oportunidad de contribuir al desarrollo de estrategias de investigación y análisis que, eventualmente, podrían apoyar en la comprensión y mitigación del impacto de esta patología en la población chilena.

# %% [markdown]
# # Data Quality Report
#
# ### Perfilado
#
# <strong>Visualizaciones generales</strong>
# * Primeras y ultimas filas
# * Descripción de las columnas (Nombre, tipo y conteo de no nulos)

# %%
# Importaciones
import pandas as pd
import numpy as np

# %%
# Carga del dataframe y visualización de las primeras 5 columnas
df = pd.read_csv('./paired_bladder_2022_clinical_data.tsv', sep="\t", encoding="utf-8")

df.head(5)
# Out:
#               Study ID Patient ID          Sample ID  Age at Diagnosis  \
# 0  paired_bladder_2022  P-0000034  P-0000034-T01-IM3              75.0
# 1  paired_bladder_2022  P-0000043  P-0000043-T02-IM3              50.0
# 2  paired_bladder_2022  P-0000056  P-0000056-T01-IM3              57.0
# 3  paired_bladder_2022  P-0000063  P-0000063-T01-IM3              61.0
# 4  paired_bladder_2022  P-0000068  P-0000068-T01-IM3              77.0
#
#   Age at Which Sequencing was Reported (Years)     Cancer Type  \
# 0                                           78  Bladder Cancer
# 1                                           58  Bladder Cancer
# 2                                           60  Bladder Cancer
# 3                                           63  Bladder Cancer
# 4                                           80  Bladder Cancer
#
#            Cancer Type Detailed         Ethnicity Category  \
# 0  Bladder Urothelial Carcinoma  Non-Spanish; Non-Hispanic
# 1  Bladder Urothelial Carcinoma                        NaN
# 2  Bladder Urothelial Carcinoma  Non-Spanish; Non-Hispanic
# 3  Bladder Urothelial Carcinoma  Non-Spanish; Non-Hispanic
# 4  Bladder Urothelial Carcinoma  Non-Spanish; Non-Hispanic
#
#    Fraction Genome Altered Gene Panel  ... Sample coverage Sample Type   Sex  \
# 0                   0.1591  IMPACT341  ...           461.0     Primary  Male
# 1                   0.4515  IMPACT341  ...           833.0  Metastasis   NaN
# 2                   0.0689  IMPACT341  ...          1004.0     Primary  Male
# 3                   0.5047  IMPACT341  ...           900.0     Primary  Male
# 4                   0.0052  IMPACT341  ...           973.0  Metastasis  Male
#
#    Smoker Somatic Status  Specimen Stage Systemic Treatment  \
# 0  Former        Matched             4.0                  1
# 1  Active        Matched             4.0                  1
# 2  Active        Matched             3.0                  1
# 3   Never        Matched             3.0                  1
# 4  Former        Matched             4.0                  0
#
#    TMB (nonsynonymous) Tumor Purity  \
# 0            13.309864           40
# 1            29.947193           50
# 2             5.545777           60
# 3            15.528174           70
# 4             3.327466           20
#
#   Treatment between Pri-Met sample collection
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# [5 rows x 35 columns]

# %%
# Visualización de las últimas 5 columnas
df.tail(5)
# Out:
#                  Study ID Patient ID          Sample ID  Age at Diagnosis  \
# 1654  paired_bladder_2022  P-0015660  s_C_E4UHYD_P001_d               NaN
# 1655  paired_bladder_2022  P-0033364  s_C_F75LKW_M001_d               NaN
# 1656  paired_bladder_2022  P-0015663  s_C_F8A03J_M001_d               NaN
# 1657  paired_bladder_2022  P-0034906  s_C_N0LN75_P001_d               NaN
# 1658  paired_bladder_2022  P-0015920  s_C_YKYKUT_P001_d               NaN
#
#      Age at Which Sequencing was Reported (Years)  \
# 1654                                          NaN
# 1655                                          NaN
# 1656                                          NaN
# 1657                                          NaN
# 1658                                          NaN
#
#                        Cancer Type   Cancer Type Detailed  \
# 1654  Bladder/Urinary Tract Cancer  Bladder/Urinary Tract
# 1655  Bladder/Urinary Tract Cancer  Bladder/Urinary Tract
# 1656  Bladder/Urinary Tract Cancer  Bladder/Urinary Tract
# 1657  Bladder/Urinary Tract Cancer  Bladder/Urinary Tract
# 1658  Bladder/Urinary Tract Cancer  Bladder/Urinary Tract
#
#              Ethnicity Category  Fraction Genome Altered Gene Panel  ...  \
# 1654  Non-Spanish; Non-Hispanic                   0.1831  IMPACT468  ...
# 1655  Non-Spanish; Non-Hispanic                   0.4761  IMPACT468  ...
# 1656  Non-Spanish; Non-Hispanic                   0.2607  IMPACT468  ...
# 1657  Non-Spanish; Non-Hispanic                   0.8778  IMPACT468  ...
# 1658  Non-Spanish; Non-Hispanic                   0.7014  IMPACT468  ...
#
#      Sample coverage Sample Type     Sex  Smoker Somatic Status  \
# 1654           378.0     Primary    Male  Former            NaN
# 1655           933.0  Metastasis    Male  Former            NaN
# 1656           867.0  Metastasis  Female  Active            NaN
# 1657           562.0     Primary  Female  Former            NaN
# 1658           647.0     Primary    Male  Former            NaN
#
#       Specimen Stage Systemic Treatment  TMB (nonsynonymous) Tumor Purity  \
# 1654             NaN                NaN             6.917585          NaN
# 1655             NaN                NaN             9.511679          NaN
# 1656             NaN                NaN             6.052887          NaN
# 1657             NaN                NaN             6.917585          NaN
# 1658             NaN                NaN            41.505509          NaN
#
#      Treatment between Pri-Met sample collection
# 1654                                       Chemo
# 1655                                       Naive
# 1656                                       Naive
# 1657                                       Chemo
# 1658                                       Naive
#
# [5 rows x 35 columns]

# %%
# Informe de calidad de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1659 entries, 0 to 1658
# Data columns (total 35 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Study ID                                      1659 non-null   object
#  1   Patient ID                                    1659 non-null   object
#  2   Sample ID                                     1659 non-null   object
#  3   Age at Diagnosis                              1272 non-null   float64
#  4   Age at Which Sequencing was Reported (Years)  1506 non-null   object
#  5   Cancer Type                                   1659 non-null   object
#  6   Cancer Type Detailed                          1659 non-null   object
#  7   Ethnicity Category                            1647 non-null   object
#  8   Fraction Genome Altered                       1526 non-null   float64
#  9   Gene Panel                                    1659 non-null   object
#  10  Intravesical Treatment                        1313 non-null   object
#  11  Met Location                                  293 non-null    object
#  12  Metastatic Site                               319 non-null    object
#  13  MSI Score                                     1632 non-null   float64
#  14  MSI Type                                      1501 non-null   object
#  15  Mutation Count                                1621 non-null   float64
#  16  Oncotree Code                                 1659 non-null   object
#  17  Overall Survival (Months)                     1582 non-null   float64
#  18  Overall Survival Status                       1657 non-null   object
#  19  Pediatric Case Indicator                      1657 non-null   object
#  20  Primary Tumor Site                            1642 non-null   object
#  21  Race Category                                 1657 non-null   object
#  22  Religion                                      1657 non-null   object
#  23  Sample Class                                  1659 non-null   object
#  24  Number of Samples Per Patient                 1659 non-null   int64
#  25  Sample coverage                               1652 non-null   float64
#  26  Sample Type                                   1659 non-null   object
#  27  Sex                                           1657 non-null   object
#  28  Smoker                                        1439 non-null   object
#  29  Somatic Status                                1643 non-null   object
#  30  Specimen Stage                                1313 non-null   float64
#  31  Systemic Treatment                            1299 non-null   object
#  32  TMB (nonsynonymous)                           1659 non-null   float64
#  33  Tumor Purity                                  1494 non-null   object
#  34  Treatment between Pri-Met sample collection   293 non-null    object
# dtypes: float64(8), int64(1), object(26)
# memory usage: 453.8+ KB

# %%
df['Age at Which Sequencing was Reported (Years)'].head(10)
# Out:
# 0    78
# 1    58
# 2    60
# 3    63
# 4    80
# 5    67
# 6    38
# 7    58
# 8    75
# 9    64
# Name: Age at Which Sequencing was Reported (Years), dtype: object

# %% [markdown]
# A simple vista, las variables <code>Treatment between Pri-Met sample collection</code>, <code>Met Location</code> y <code>Metastatic Site</code> poseen muy pocos valores no nulos, ademas la columna <code>Age at Which Sequencing was Reported (Years)</code> y `Intravesical Treatment` aparecen como tipo `object` a pesar de ser numericos.

# %% [markdown]
# <strong>Rango de valores numéricos</strong>

# %%
df.describe()
# Out:
#        Age at Diagnosis  Fraction Genome Altered    MSI Score  Mutation Count  \
# count       1272.000000              1526.000000  1632.000000     1621.000000
# mean          65.165881                 0.180792     0.645938       14.474399
# std           11.270300                 0.177171     2.597361       22.966564
# min            0.000000                 0.000000    -1.000000        1.000000
# 25%           58.000000                 0.027900     0.000000        6.000000
# 50%           66.000000                 0.128650     0.160000       10.000000
# 75%           73.000000                 0.288575     0.650000       16.000000
# max           92.000000                 0.954500    42.110000      469.000000
#
#        Overall Survival (Months)  Number of Samples Per Patient  \
# count                1582.000000                    1659.000000
# mean                   32.630613                       1.665461
# std                    24.624368                       0.948407
# min                     0.000000                       1.000000
# 25%                    12.600000                       1.000000
# 50%                    28.570000                       1.000000
# 75%                    44.827500                       2.000000
# max                   104.877000                       6.000000
#
#        Sample coverage  Specimen Stage  TMB (nonsynonymous)
# count      1652.000000     1313.000000          1659.000000
# mean        693.682203        2.892612            15.965241
# std         321.043195        0.744829            22.565535
# min          57.000000        1.000000             0.000000
# 25%         512.000000        3.000000             5.872318
# 50%         638.000000        3.000000            10.376377
# 75%         782.000000        3.000000            19.023358
# max        2641.000000        4.000000           404.678709

# %% [markdown]
# Se puede observar en el minimo de la columna <code>Age at Diagnosis</code> que hay un valor atípico de 0, lo cual no tiene sentido clínico. Tambien se puede notar que el `MSI Score` tiene un valor mínimo de -1, lo cual biologicamente no tiene sentido.

# %% [markdown]
# <strong>Valores únicos y duplicados</strong>

# %%
categorias = df.select_dtypes(exclude="number").apply(lambda x: x.unique())

for col, vals in categorias.items():
    print(f"Valores únicos en '{col}': {vals}")
# Out:
# Valores únicos en 'Study ID': ['paired_bladder_2022']
# Valores únicos en 'Patient ID': ['P-0000034' 'P-0000043' 'P-0000056' ... 'P-0067727' 'P-0067776'
#  'P-0067920']
# Valores únicos en 'Sample ID': ['P-0000034-T01-IM3' 'P-0000043-T02-IM3' 'P-0000056-T01-IM3' ...
#  's_C_F8A03J_M001_d' 's_C_N0LN75_P001_d' 's_C_YKYKUT_P001_d']
# Valores únicos en 'Age at Which Sequencing was Reported (Years)': ['78' '58' '60' '63' '80' '67' '38' '75' '64' '65' '50' '69' '59' '81'
#  '45' '66' '61' '72' '73' '79' '54' '68' '89' '87' '83' '44' '70' '56'
#  '71' '39' '74' '57' '82' '76' '53' '77' nan '52' '33' '49' '28' '86' '55'
#  '51' '85' '46' '90' '62' '84' '88' '40' '48' '47' '42' '>90' '35' '43'
#  '41' '29' '21' '34' '36']
# Valores únicos en 'Cancer Type': ['Bladder Cancer' 'Cancer of Unknown Primary'
#  'Bladder/Urinary Tract Cancer']
# Valores únicos en 'Cancer Type Detailed': ['Bladder Urothelial Carcinoma' 'Urethral Squamous Cell Carcinoma'
#  'Plasmacytoid/Signet Ring Cell Bladder Carcinoma'
#  'Upper Tract Urothelial Carcinoma' 'Cancer of Unknown Primary'
#  'Urethral Urothelial Carcinoma' 'Undifferentiated Malignant Neoplasm'
#  'Sarcomatoid Carcinoma of the Urinary Bladder' 'Urethral Cancer'
#  'Poorly Differentiated Carcinoma, NOS' 'Urothelial Papilloma'
#  'Small Cell Bladder Cancer' 'Small Cell Carcinoma of Unknown Primary'
#  'Bladder Squamous Cell Carcinoma' 'Bladder Adenocarcinoma'
#  'Adenocarcinoma, NOS' 'Urachal Adenocarcinoma'
#  'Neuroendocrine Carcinoma, NOS' 'Bladder/Urinary Tract']
# Valores únicos en 'Ethnicity Category': ['Non-Spanish; Non-Hispanic' nan 'Spanish  NOS; Hispanic NOS, Latino NOS'
#  'Unknown whether Spanish or not' 'Cuban' 'Puerto Rican'
#  'Mexican (includes Chicano)' 'South/Central America (except Brazil)']
# Valores únicos en 'Gene Panel': ['IMPACT341' 'IMPACT468' 'IMPACT410' 'ACCESS129' 'IMPACT505']
# Valores únicos en 'Intravesical Treatment': ['0' '3' '1' nan '2' '.']
# Valores únicos en 'Met Location': [nan 'Distant' 'Ln']
# Valores únicos en 'Metastatic Site': [nan 'Liver' 'Lymph Node' 'Lung' 'Lymph node' 'Colon' 'Prostate' 'Pelvis'
#  'Bone' 'Subcutaneous Tissue' 'Pubic bone' 'Abdomen' 'Blood' 'liver'
#  'Epidural' 'Right Ischium' 'Soft Tissue' 'Adrenal Gland' 'Brain' 'Pleura'
#  'Cervix' 'Penis' 'Retroperitoneum' 'Perinephric Mass' 'Skin' 'Omentum'
#  'Pleural Fluid' 'Urethra' 'Neck' 'Vagina' 'Sigmoid Colon'
#  'Small Intestine' 'Breast' 'Chest Wall']
# Valores únicos en 'MSI Type': ['Stable' 'Indeterminate' 'Do not report' nan 'Instable']
# Valores únicos en 'Oncotree Code': ['BLCA' 'USCC' 'SRCBC' 'UTUC' 'CUP' 'UCU' 'UDMN' 'SCB' 'UCA' 'PDC' 'UPA'
#  'SCBC' 'SCUP' 'BLSC' 'BLAD' 'ADNOS' 'UA' 'NECNOS' 'BLADDER']
# Valores únicos en 'Overall Survival Status': ['1:DECEASED' nan '0:LIVING']
# Valores únicos en 'Pediatric Case Indicator': ['No' nan 'Yes']
# Valores únicos en 'Primary Tumor Site': ['Bladder' 'Urethra' 'Upper Tract' 'Renal Pelvis' 'Unknown' 'Ureter'
#  'Pelvis' nan 'Kidney/Upper Tract' 'bladder' 'Kidney/Upper tract' 'Lung']
# Valores únicos en 'Race Category': ['WHITE' nan 'BLACK OR AFRICAN AMERICAN' 'ASIAN-FAR EAST/INDIAN SUBCONT'
#  'PT REFUSED TO ANSWER' 'NATIVE AMERICAN-AM IND/ALASKA' 'OTHER'
#  'NO VALUE ENTERED' 'UNKNOWN']
# Valores únicos en 'Religion': ['CHRISTIAN' nan 'NONE' 'JEWISH' 'CATHOLIC/ROMAN' 'EPISCOPALIAN'
#  'LUTHERAN' 'PROTESTANT' 'HINDU' 'GREEK ORTHODOX' 'BAPTIST' 'PRESBYTERIAN'
#  'MORMAN' 'OTHER' 'UNKNOWN' 'MUSLIM' 'METHODIST' 'CHRISTIAN ORTHODOX'
#  'BUDDHIST' 'UNITARIAN' 'SPIRITUAL NOT RELIG' 'PENTECOSTAL'
#  'NO VALUE ENTERED' 'SEVEN DAY ADVENTIST' 'JEHOVAH WITNESS' 'SIKH']
# Valores únicos en 'Sample Class': ['Tumor' 'cfDNA' 'Resection' 'Biopsy']
# Valores únicos en 'Sample Type': ['Primary' 'Metastasis' 'Unknown' 'Local Recurrence' 'Unknown_Tumor']
# Valores únicos en 'Sex': ['Male' nan 'Female']
# Valores únicos en 'Smoker': ['Former' 'Active' 'Never' nan]
# Valores únicos en 'Somatic Status': ['Matched' 'Unmatched' nan]
# Valores únicos en 'Systemic Treatment': ['1' '0' nan '3' '.' '2']
# Valores únicos en 'Tumor Purity': ['40' '50' '60' '70' '20' '30' '80' '90' '75' nan '15' '10' '85' '5' '46'
#  '<10' '100']
# Valores únicos en 'Treatment between Pri-Met sample collection': [nan 'Chemo' 'Naive' 'Both' 'IO']

# %% [markdown]
# Al revisar los valores únicos, se pueden observar inconsistencias como:
# * En `Age at Which Sequencing was Reported (Years)` se ve el valor >90 a pesar de que el resto es númerico
# * Solapamiento en la columna `Cancer Type` entre los valores 'Bladder Cancer' y 'Bladder/Urinary Tract Cancer'
# * En `Metastatic Site` se encuentran las categorías duplicadas de:
#   * 'Lymph Node' y 'Lymph node'
#   * Problemas de granularidad en 'Pubic bone' y 'Bone'
# * En `MSI Type` hay un error ortografico en ingles, donde se usa la categoria 'Instable' en vez de la palabra correcta que es 'Unstable', ademas de estar la categoria 'Do not report' que es lo mismo que tener un valor nulo
# * En la columna `Oncotree Code` 'BLADDER' y 'BLCA' son lo mismo, pasa lo mismo con 'Kidney/Upper Tract' y 'Kidney/Upper tract' y 'Pelvis' con 'Renal Pelvis'
# * En la columna 'Race Category' tanto 'PT REFUSED TO ANSWER' como 'OTHER' para efectos del estudio prodian considerarse como nulos.

# %% [markdown]
# <strong>Outliers</strong>

# %%
numeric_cols = df.select_dtypes(include=np.number)

z_scores = (numeric_cols - numeric_cols.mean()) / numeric_cols.std()

outliers_por_col = (z_scores.abs() > 3).sum()

outliers_pct = ((z_scores.abs() > 3).sum() / len(df)) * 100

outliers_summary = pd.DataFrame({
    "cantidad_outliers": outliers_por_col,
    "porcentaje_outliers": outliers_pct.round(2)
})

print(outliers_summary)
# Out:
#                                cantidad_outliers  porcentaje_outliers
# Age at Diagnosis                               8                 0.48
# Fraction Genome Altered                        9                 0.54
# MSI Score                                     20                 1.21
# Mutation Count                                10                 0.60
# Overall Survival (Months)                      0                 0.00
# Number of Samples Per Patient                 27                 1.63
# Sample coverage                               44                 2.65
# Specimen Stage                                 0                 0.00
# TMB (nonsynonymous)                           19                 1.15

# %% [markdown]
# Podemos observar que `Sample coverage` es la columna con más outliers, tanto en cantidad como en porcentaje. Los outliers se mueven en un rango entre 0 y 44, teniendo en cuenta que es un dataset de mas de 1000 pacientes, son un porcentaje asumible.
